# %% [markdown]
# ### Simple Linear Regression
# Dataset: placement.csv
# Approach: From Scratch / Sklearn

# %%
import pandas as pd 
from sklearn import linear_model

df = pd.read_csv('placement.csv')
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
X = df.drop(['package'], axis=1)

# %%
y = df['package']
